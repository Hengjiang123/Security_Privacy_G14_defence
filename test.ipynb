# %%
import sqlite3
import pandas as pd

# %%
# connect to the SQLite database
conn = sqlite3.connect("bank.db")

# acquire user from dataset
df_users = pd.read_sql_query("SELECT * FROM users", conn)
display(df_users)

# acquire transactions from dataset
df_transactions = pd.read_sql_query("SELECT * FROM transactions", conn)
display(df_transactions)

# close the connection
conn.close()
# Out:
#     id    account_no                          username  \
# 0    1  409000611074                 user_409000611074
# 1    2  409000493201                 user_409000493201
# 2    3  409000425051                 user_409000425051
# 3    4  409000405747                 user_409000405747
# 4    5  409000438611                 user_409000438611
# 5    6  409000493210                 user_409000493210
# 6    7  409000438620                 user_409000438620
# 7    8       1196711                      user_1196711
# 8    9       1196428                      user_1196428
# 9   10  409000362497                 user_409000362497
# 10  11           123                           user123
# 11  12        999999  "><script>alert('XSS!')</script>
# 12  13      12345678                          12345678
# 13  14        123456                               LHJ
# 14  15       1234567                              LHJ1
# 15  16       1234562                              LHJ2
# ...

# %%
conn = sqlite3.connect('bank.db')
conn.execute('ALTER TABLE users ADD COLUMN totp_secret TEXT')
conn.commit()
conn.close()

# %%
import pyotp
import qrcode

# TOTP secret key
secret = "YAL34UYQB7M4ILF2M43OEAKIN2GRBQ7N"

totp_uri = pyotp.totp.TOTP(secret).provisioning_uri(name="demo_user", issuer_name="DigitalBank")

print("TOTP URI for QR code:")
print(totp_uri)

img = qrcode.make(totp_uri)

img.show()
# Out:
# TOTP URI for QR code:
# otpauth://totp/DigitalBank:demo_user?secret=YAL34UYQB7M4ILF2M43OEAKIN2GRBQ7N&issuer=DigitalBank
